# %% [markdown]
# ## Colormaps
#
# Custom colormaps can be a useful tool to quickly draw attention to parts
# of an image.

# %% [markdown]
# ### Data
#
# This is a merged dataset for _IGR J14003-6326_, aka _G310.6-1.6_.
#
#
# ```bash
# find_chandra_obsid 'IGR J14003-6326' download=all
# reproject_obs "*/primary/*evt*" outroot=G310.6-1.6 bin=1
#
# ```

# %%
cd LUT
ds9 G310.6-1.6_merged_evt.fits -pan to 4096.5 4096.5 -bin factor 1 -scale log -smooth yes &
# Out:
# [1] 20028

# %%
import -window "SAOImage ds9" ds9_06_lut_01.png 
display < ds9_06_lut_01.png

# %%
xpaset -p ds9 cmap load $ASCDS_INSTALL/contrib/data/vt2.lut 

import -window "SAOImage ds9" ds9_06_lut_02.png 
display < ds9_06_lut_02.png

# %%
xpaset -p ds9 quit
# Out:
# [1]+  Done                    ds9 G310.6-1.6_merged_evt.fits -pan to 4096.5 4096.5 -bin factor 1 -scale log -smooth yes
